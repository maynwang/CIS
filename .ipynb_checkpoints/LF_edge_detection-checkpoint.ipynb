# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import xarray as xr
import cartopy
import cartopy.crs as ccrs
from landfast_ice_detection import landfast_ice_detection
from datetime import date 
from netCDF4 import Dataset



# input data directory
path = '/extra-space1/data/tikoralukupload/cis-weekly/nc/'

# region of interest
region = 'HB'

nc = Dataset(path + region + '.nc', 'r')
juld = nc.variables['juld'][:]

# Date time information
d0ord = date(1950,1,1).toordinal()
dt_ordinal = d0ord + juld
dates = [date.fromordinal(dt_ordinal[tt]) for tt in range(len(juld))]

# %%
date_str = '2020-04-27'
lf_lon, lf_lat, edge_dist, lf_area = landfast_ice_detection(date_str)
# Out:
# The total area of landfast sea ice is 10885.0 km^2

# %%
edge_dist
# Out:
# array([   0.        , 1000.        , 1414.21356237, ...,    0.        ,
#           0.        ,    0.        ])
