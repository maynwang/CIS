# %%
import numpy as np 
import cmocean
import cmocean.cm as cmo
import xarray as xr   
from pathlib import Path
from netCDF4 import Dataset
import glob
import matplotlib.pyplot as plt
import cartopy
import cartopy.crs as ccrs
import datetime 
from datetime import date 
import mpl_toolkits.basemap as bm
import matplotlib.animation as animation
import numpy.ma as ma
import matplotlib.cm as cm
from matplotlib.patches import Polygon
from scipy import signal, stats
import time
import cv2
from mpl_toolkits.axes_grid1 import make_axes_locatable
import warnings; warnings.simplefilter('ignore')

from functions import load_ice, trend, find_trends, plot_cartopy, decomp

# input data directory
path = Path('/extra-space1/data/tikoralukupload/cis-weekly/nc/')

# region of interest
region = 'HB'

# Projection for mapping
rot = ccrs.RotatedPole(pole_latitude=55,pole_longitude=150)

# Construct the full file name
fname = path / '{}.nc'.format(region)

### Load data into a `xarray.Dataset`:
# Note that the data is loaded lazily which means that no actual data are actually written
# into memory.
ds = xr.open_dataset(fname)

juld = ds.juld

# subset `xarray.Dataset` by index
ds = ds.isel(x=slice(1700, None), y=slice(600, 1450))


# create shortcuts to the variables
lon = ds.longitude
lat = ds.latitude
land = ds.land
E_FA = ds['E_FA']
E_CT = ds['E_CT']

CT = np.nan*np.ones(E_CT.shape)
CT[E_CT==1] = 10
CT[E_CT==2] = 20
CT[E_CT==3] = 30
CT[E_CT==4] = 40
CT[E_CT==5] = 50
CT[E_CT==6] = 60
CT[E_CT==7] = 70
CT[E_CT==8] = 80
CT[E_CT==9] = 90
CT[E_CT==10] = 95
CT[E_CT==11] = 100

# %%
### Decompose time series yearly

eggcode = CT
years = juld.dt.year
months = juld.dt.month

years_unique = np.unique(years)
n = np.shape(lon)[0] # shape of lon
m = np.shape(lat)[1]
# Calculate monthly means and subtract them from time series
ybar=[]
darr=[]
year_occurences = []


for yr in years_unique:
    # Every year for the month defined by mon
    which = (years == yr)
    if np.sum(which) >= 1:
        # Save all observational days of the month
        inds = np.where(which)[0]
#         date_str.append(dates[k].strftime("%Y-%m-%d"))
        # yearly means
        ybar.append(np.nanmean(eggcode[inds,:,:],axis=0))
        # Subtract mean from time series
        darr.append(eggcode[inds,:,:] - np.nanmean(eggcode[inds,:,:],axis=0))
        # Indices of dates within each month
        year_occurences.append(juld[inds])

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(1,1,1, projection=rot)
plot_cartopy(ax,lon,lat)
plt.pcolor(lon,lat,ybar[0],transform=ccrs.PlateCarree(), zorder=4)

# plt.contourf(lon,lat,ybar[1])

# %%
np.shape(year_occurences[0])
# Out:
# (31,)

# %%
n = np.shape(lon)[0]
m = np.shape(lon)[1]

ytrend = np.zeros((len(ybar),n,m))
dtrend_95 = np.zeros((len(ybar),n,m))

# Calculate trends along time axis
for yr in range(len(years_unique)):
    for i in range(n):
        for j in range(m):
#             idx = np.isfinite(month_occurences[month]) & np.isfinite(dCT_monthly[month][:,i,j])
#             if idx.any()==True:
            mean, tr, dt95 = trend(year_occurences[yr], darr[yr][:,i,j])
            ytrend[yr,i,j] = tr
            dtrend_95[yr,i,j] = dt95

toc = time.time()
print(toc-tic)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-85-95db233e42bd> in <module>
#      11 #             idx = np.isfinite(month_occurences[month]) & np.isfinite(dCT_monthly[month][:,i,j])
#      12 #             if idx.any()==True:
# ---> 13             mean, tr, dt95 = trend(year_occurences[yr].values, darr[yr][:,i,j])
#      14             ytrend[yr,i,j] = tr
#      15             dtrend_95[yr,i,j] = dt95
#
# /misc/home/mwang/CIS-project/code/functions.py in trend(x, y, alpha)
#      32         return np.nan, np.nan, np.nan
#      33     else:
# ---> 34         X = np.array([np.ones(len(x)), x-x.mean()])
#      35         beta = np.linalg.lstsq(X[:,valid].T, y[valid])[0]
#      36         yhat = np.sum(beta*X.T, axis=1)
#
# ~/miniconda3/envs/py3/lib/python3.9/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#     158             is_float16_result = True
#     159
# --> 160     ret = umr_sum(arr, axis, dtype, out, keepdims)
#     161     if isinstance(ret, mu.ndarray):
#     162         ret = um.true_divide(
#
# UFuncTypeError: ufunc 'add' cannot use operands with types dtype('<M8[ns]') and dtype('<M8[ns]')

# %%
year_occurences[0]
# Out:
# <xarray.DataArray 'juld' (juld: 31)>
# array(['1997-01-01T00:00:00.000000000', '1997-02-01T00:00:00.000000000',
#        '1997-03-01T00:00:00.000000000', '1997-04-01T00:00:00.000000000',
#        '1997-05-01T00:00:00.000000000', '1997-05-15T00:00:00.000000000',
#        '1997-06-12T00:00:00.000000000', '1997-06-19T00:00:00.000000000',
#        '1997-06-26T00:00:00.000000000', '1997-07-03T00:00:00.000000000',
#        '1997-07-10T00:00:00.000000000', '1997-07-17T00:00:00.000000000',
#        '1997-07-24T00:00:00.000000000', '1997-07-31T00:00:00.000000000',
#        '1997-08-07T00:00:00.000000000', '1997-08-14T00:00:00.000000000',
#        '1997-08-21T00:00:00.000000000', '1997-08-28T00:00:00.000000000',
#        '1997-09-04T00:00:00.000000000', '1997-09-11T00:00:00.000000000',
#        '1997-09-18T00:00:00.000000000', '1997-09-25T00:00:00.000000000',
#        '1997-10-02T00:00:00.000000000', '1997-10-09T00:00:00.000000000',
#        '1997-10-16T00:00:00.000000000', '1997-10-23T00:00:00.000000000',
#        '1997-10-30T00:00:00.000000000', '1997-11-06T00:00:00.000000000',
#        '1997-11-13T00:00:00.000000000', '1997-11-20T00:00:00.000000000',
#        '1997-12-01T00:00:00.000000000'], dtype='datetime64[ns]')
# Coordinates:
#   * juld     (juld) datetime64[ns] 1997-01-01 1997-02-01 ... 1997-12-01
# Attributes:
#     long_name:  juld
